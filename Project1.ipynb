# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepakKaradi/addressbook/blob/master/Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain-huggingface
# !pip install huggingface_hub
# !pip install transformers
# !pip install accelerate
# !pip install bitsandbytes
# !pip install langchain
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 11.8 MB/s eta 0:00:00
# ...

# %%
# Out:
# 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

# %%
from langchain_huggingface import HuggingFaceEndpoint
from google.colab import userdata
sec_key = userdata.get('HF_TOKEN')
print(sec_key)

import os
os.environ['HUGGINGFACE'] = sec_key
# Out:
# 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

# %%
repo_id = "medicalai/ClinicalBERT"
llm = HuggingFaceEndpoint(repo_id = repo_id, max_length=128, temperature =0.7, token = sec_key)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.

# %%
llm.invoke("Is a big lump in breast dangerous")
# Out:
# "? A lump in the breast can be a sign of many different conditions, some of which are serious and some of which are not. It's important to have any lump in the breast evaluated by a healthcare provider to determine the cause. Some possible causes of a lump in the breast include:\n\n1. Cyst: A fluid-filled sac that can form in the breast tissue. Cysts are usually not cancerous and are common in women of childbearing age.\n2. Fibroadenoma: A benign (non-cancerous) tumor made up of breast tissue. Fibroadenomas are usually smooth, round, and movable.\n3. Fat necrosis: The death of fat tissue in the breast, which can cause a lump to form. This can occur after an injury to the breast.\n4. Inflammatory breast cancer: A rare and aggressive form of breast cancer that causes the breast to become red, swollen, and warm.\n5. Breast cancer: A malignant (cancerous) growth in the breast tissue. Breast cancer is the most common type of cancer in women.\n\nIf you have a lump in your breast, it's impo
# ...

# %%
from langchain import PromptTemplate, LLMChain
question = "What are symptoms of Breast cancer?"
template = """Question: {question} Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=["question"])
llm_chain = LLMChain(llm=llm, prompt=prompt)
print(llm_chain.invoke(question))
# Out:
# {'question': 'What are symptoms of Breast cancer?', 'text': "\n\n1. Breast lump or thickening: Most breast lumps are not cancer, but if you feel a lump in your breast or underarm area, it's important to have it checked by a healthcare provider.\n\n2. Change in size or shape of the breast: If one breast becomes significantly larger or lower than the other, or if the nipple or breast indentation changes, it could be a sign of breast cancer.\n\n3. Nipple changes: Changes such as the nipple turning inward, redness, scaling, or discharge (especially if it's bloody) could be a sign of breast cancer.\n\n4. Skin changes: Dimpling, puckering, or redness of the skin over the breast could be a sign of breast cancer.\n\n5. Pain: While many women experience breast pain, persistent pain in one area of the breast can sometimes be a sign of breast cancer.\n\n6. Swelling in the armpit or around the collarbone: This could be a sign of swollen lymph nodes, which can be a sign of breast cancer.\n\n7. Ch
# ...

# %%
from langchain_huggingface import HuggingFacePipeline
# from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
# from langchain import PromptTemplate, LLMChain

from transformers import AutoTokenizer, AutoModel
tokenizer = AutoTokenizer.from_pretrained("medicalai/ClinicalBERT")
model = AutoModel.from_pretrained("medicalai/ClinicalBERT")

pipe = pipeline("text-generation", model=model, tokenizer=tokenizer, max_length=128, temperature =0.7)
# Out:
# tokenizer_config.json:   0%|          | 0.00/62.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/542M [00:00<?, ?B/s]
# ...
